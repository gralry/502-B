# %% [markdown]
# # Compiladores

# %% [markdown]
# # Código de la clase
# - ## zuolshkb

# %%
'''
int main@(){
    int a21, 2b;
}
'''
# Out:
# '\nint main@(){\n    int a21, 2b;\n}\n'

# %% [markdown]
# # Proyecto Analizador Léxico
#
# ### Contamos con el alfabeto
# - letra = a-zA-Z
# ### El siguiente autómata reconoce comandos
#
# - ->0-letra->1(id)<=letra>
#
# ### Para la línea 1, como @ no está definida obtenemos
# - #linea | token | lexema
# -   1   |  id   |  int
# -    1   |  id   |  main
# - linea 1:9: Error léxico @ no definido
#
# ### Teniendo en cuenta el siguiente generador:
# - D -> T id L ;
# - L -> €
# - L -> ',', id, L;
# - T -> int
# - T -> float

# %% [markdown]
# ## Analizador Léxico

# %% [markdown]
# ### Salidas
# - Tiras de tokens
# - Tabla de simbolos
# - Mensajes de errores

# %% [markdown]
# ## Conversión de comentarios

# %% [markdown]
# Se debe detectar los comentarios para poder descartarlos, aunque en este proceso de traduccion de lenguajes puede convenir la transmisión de comentarios

# %% [markdown]
# ## Tareas

# %% [markdown]
# - Formar el equipo
# - Definir Lenguaje Fuente c/ Lenguaje Objeto
# - Dibujar el automata
